# %% [markdown]
# Es importante instalar las librerias:
# pip install pandas

# %%
import pandas as pd
df = pd.read_csv("resultados.csv")

# %%
headers_names = ["ID", "Fecha", "Dominio", "Título", "URL", "Idioma", "Sentimiento", "Telefonos", "Emails"]
df.columns=headers_names
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           28 non-null     int64
#  1   Fecha        28 non-null     object
#  2   Dominio      28 non-null     object
#  3   Título       28 non-null     object
#  4   URL          28 non-null     object
#  5   Idioma       28 non-null     object
#  6   Sentimiento  28 non-null     object
#  7   Telefonos    28 non-null     object
#  8   Emails       28 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ KB

# %%
df["Fecha"] = pd.to_datetime(df["Fecha"])
print(type(df.Fecha[1]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df.sort_values(by="Fecha")
# Out:
#     ID                            Fecha
# 21  22        2022-07-11 00:00:00+00:00  \
# 9   10        2022-08-03 00:00:00+00:00
# 20  21        2022-10-10 00:00:00+00:00
# 17  18        2022-10-10 00:00:00+00:00
# 25  26        2022-10-24 00:00:00+00:00
# 13  14        2022-11-09 00:00:00+00:00
# 15  16        2022-11-09 00:00:00+00:00
# 14  15        2022-11-09 00:00:00+00:00
# 12  13        2022-11-11 00:00:00+00:00
# 7    8        2022-11-18 00:00:00+00:00
# 8    9        2022-11-18 00:00:00+00:00
# 10  11        2022-11-19 00:00:00+00:00
# 0    1        2022-12-07 00:00:00+00:00
# 4    5        2022-12-07 00:00:00+00:00
# 3    4        2022-12-07 00:00:00+00:00
# 2    3        2022-12-07 00:00:00+00:00
# 1    2        2022-12-07 00:00:00+00:00
# 18  19        2022-12-23 00:00:00+00:00
# 6    7        2023-01-16 00:00:00+00:00
# 5    6        2023-01-16 00:00:00+00:00
# 16  17        2023-01-23 00:00:00+00:00
# 11  12        2023-02-24 00:00:00+00:00
# ...

# %%
df["Dominio"].value_counts().to_frame()
# Out:
#                                                     count
# Dominio
# elespanol                                               9
# galiciapress                                            5
# rtve                                                    4
# tuttosport                                              2
# eitb                                                    1
# com/espana/2023-04-17/28-m-los-alcaldes-sociali...      1
# com/espana/2023-01-16/caballero-calcula-tres-mi...      1
# com/espana/galicia/2022-11-19/abel-caballero-pr...      1
# gazzetta                                                1
# elledecor                                               1
# tio                                                     1
# corrieredellosport                                      1
